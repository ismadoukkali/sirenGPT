# %% [markdown]
# ### sirentGPT - Client Scalability

# %%
import functions_framework
from openai import OpenAI
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
from urllib.request import urlopen, Request
from dotenv import load_dotenv
import threading
from datetime import datetime
import json
import os
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from urllib.parse import urljoin, urlparse

load_dotenv()
client = OpenAI()

# %%
def generate_response(prompt):
    response = client.chat.completions.create(
    model="gpt-4-1106-preview",
    response_format={ "type": "json_object" },
    messages=[
        {"role": "system", "content": "You are a helpful assistant, expert in Analysing Companies."},
        {"role": "user", "content": str(prompt)},
    ],
    temperature=0
    )
    selection = response.choices[0].message.content
    return selection

def generate_response_feedback(initial_question, system_answer, feedback):
    response = client.chat.completions.create(
    model="gpt-4-1106-preview",
    response_format={ "type": "json_object" },
    messages=[
        {"role": "system", "content": "You are a helpful assistant, expert in Analysing Companies."},
        {"role": "user", "content": str(initial_question)},
        {"role": "system", "content": str(system_answer)},
        {"role": "user", "content": str(feedback)}
    ],
    temperature=0
    )
    selection = response.choices[0].message.content
    return selection

def generate_response_gpt3(prompt):
    response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a helpful assistant, expert in Analysing Companies."},
        {"role": "user", "content": str(prompt)},
    ],
    max_tokens=300,
    temperature=0
    )
    selection = response.choices[0].message.content
    return selection

def generate_response_gpt3_json(prompt):
    response = client.chat.completions.create(
    model="gpt-3.5-turbo-1106",
    response_format={ "type": "json_object" },
    messages=[
        {"role": "system", "content": "You are a helpful assistant, expert in Analysing Companies."},
        {"role": "user", "content": str(prompt)},
    ],
    max_tokens=300,
    temperature=0
    )
    selection = response.choices[0].message.content
    return selection

def retrieve_html(url):
    headers = {'User-Agent': 'Mozilla/5.0'}
    req = Request(url, headers=headers)
    html = urlopen(req).read()
    soup = BeautifulSoup(html, features="html.parser")

    for script in soup(["script", "style"]):
        script.extract() 

    text = soup.get_text()
    lines = (line.strip() for line in text.splitlines())
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    text = '\n'.join(chunk for chunk in chunks if chunk)
    return text

def get_html(html):
    soup = BeautifulSoup(html, features="html.parser")

    for script in soup(["script", "style"]):
        script.extract() 

    text = soup.get_text()
    lines = (line.strip() for line in text.splitlines())
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    text = '\n'.join(chunk for chunk in chunks if chunk)
    return str(text)

# %%
def selenium_search(query):

    API_KEY = os.environ['GOOGLE_SEARCH_API_KEY']
    SEARCH_ENGINE_ID = os.environ['SEARCH_ENGINE_ID']

    url = 'https://www.googleapis.com/customsearch/v1'

    params = {
        'key': API_KEY,
        'cx': SEARCH_ENGINE_ID,
        'q': query
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        results = response.json()

        if 'items' in results:
            return results['items'][0]['link']
        else:
            return 'No results found'
    else:
        return f'Error: {response.status_code}'

# %%
prompt_legals = ["yes", "no"]
prompt_legal = """ 

You will be given the url handle of a site.

You will need to classify if this site will direct you to the terms & conditions or legal notice of the company where we can potentially find the identification number of the SIRET/SIREN of such company.

The url paths of these site tend to be: 
/terms
/terms-of-service
/terms-and-conditions
/tos
/terms-of-use
/legal
/legal/terms
/privacy
/legal/terms-and-conditions
/user-agreement
/conditions
/terms-of-agreement

You will need to output your response in JSON format like this:

{
    "legal": yes or no
    "relevant_link": www.example.com/path-to-page
}

Here an example:

Input: https://evergrowth.com/privacy 

Output: 

{
    "legal": "true"
    "relevant_link": "https://evergrowth.com/privacy"
}

If no SIREN is found just output "legal": "Not found".

Here the page to classify:
"""

# %%
prompt_siret = """

You are given the scrapped text from a legal/terms and conditions page.

You'll need to identify and output the SIREN or SIRET identification number of the business:

Here a description of what these identification numbers are -

SIREN (Système d'Identification du Répertoire des Entreprises): This is a 9-digit identification number assigned to an individual or entity when they first register their business. This number is unique to each business entity and remains unchanged throughout the life of the business, serving as a way to identify the business in administrative procedures and documents.

SIRET (Système d'Identification du Répertoire des Établissements): This number expands on the SIREN number by adding a 5-digit serial number, referred to as NIC (Numéro Interne de Classement), making it a 14-digit number in total. The SIRET number uniquely identifies each physical location (establishment) of a business. If a business operates in multiple locations, each one will have its own SIRET number, but the initial 9-digit SIREN part will be the same for all locations.  

Output your answer in JSON format. Here an example:

{
    "siren/siret": Siren/Siret Number
}

Example Input:

"mail : siege@energys-sas.fr

SIREN : 479 767 926

TVA intracommunautaire : FR55 479737926

Capital : 75000"

Example Output:

{
    "siren/siret": "479737926"
}

If no siren/siret is found in the output put out -> {"siren/siret": "Not found"}
"""

# %%
header_siret = "Find here the scrapped text: "

# %%
def format_url(url):
    if url.startswith("http://www."):
        url = url.replace("http://www.", "https://www.")
    elif url.startswith("http://"):
        url = url.replace("http://", "https://www.")
    elif url.startswith("www."):
        url = "https://" + url
    elif not url.startswith("https://"):
        url = "https://www." + url
    return url

# %%
def retieve_url(url, html=False):
    apikey = os.getenv("ZEN_ROWS_SCRAPER")

    zenrows_api_base = "https://api.zenrows.com/v1/"

    requests_session = requests.Session()
    retries = Retry(
        total=3,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504]
    )
    requests_session.mount("https://", HTTPAdapter(max_retries=retries))

    try:
        response = requests_session.get(zenrows_api_base, params={
            "apikey": apikey,
            "url": url,
        })
        if html:
            return response.text
        else: 
            return response
    
    except Exception as e:
        print(e)  
    
    try:
        response = requests.get(zenrows_api_base, params={
            "apikey": apikey,
            "url": url,
            "block_resources": "image,media,font",
            "premium_proxy":"true"
        })
        if html:
            return response.text
        else: 
            return response

    except Exception as e:
        print(e)

# %%
def extract_all_links(base_url):

    response = retieve_url(base_url)
    try:
        soup = BeautifulSoup(response.text, 'html.parser')
        a_tags = soup.find_all('a')
        links = set()  
        links.add(base_url.rstrip('/'))
        for tag in a_tags:
            if 'href' in tag.attrs:
                full_url = urljoin(base_url, tag['href'])
                if urlparse(full_url).netloc == urlparse(base_url).netloc:
                    links.add(full_url)
    
        return links
    except Exception:
        print("Failed to retrieve the main webpage.")
        return []

# %%
import requests
import xml.etree.ElementTree as ET

def fetch_sitemap(url):
    """
    Fetches the sitemap from the given URL and parses it to extract all page URLs.

    :param url: The base URL of the website.
    :return: A list of URLs contained in the sitemap.
    """
    sitemap_urls = []
    try:
        sitemap_url = url.rstrip('/') + '/sitemap.xml'
        response = requests.get(sitemap_url)
        response.raise_for_status()  

        root = ET.fromstring(response.content)
        namespace = {'sitemap': 'http://www.sitemaps.org/schemas/sitemap/0.9'}
        if root.tag == '{http://www.sitemaps.org/schemas/sitemap/0.9}sitemapindex':
            for sitemap in root.findall('sitemap:sitemap', namespace):
                loc = sitemap.find('sitemap:loc', namespace).text
                sitemap_urls.extend(fetch_sitemap_pages(loc))
        else:
            sitemap_urls.extend(fetch_sitemap_pages(sitemap_url))

    except requests.RequestException as e:
        print(f"Failed to fetch the sitemap: {e}")
    except ET.ParseError as e:
        print(f"Failed to parse the sitemap XML: {e}")

    return sitemap_urls

def fetch_sitemap_pages(sitemap_url):
    """
    Fetches a sitemap and parses it to extract page URLs.

    :param sitemap_url: The URL of the sitemap to parse.
    :return: A list of page URLs found in the sitemap.
    """
    page_urls = []
    base_bool = True

    try:
        response = requests.get(sitemap_url)
        response.raise_for_status()

        root = ET.fromstring(response.content)
        namespace = {'sitemap': 'http://www.sitemaps.org/schemas/sitemap/0.9'}
        for url in root.findall('sitemap:url', namespace):
            loc = url.find('sitemap:loc', namespace).text
            page_urls.append(loc)

    except requests.RequestException as e:
        print(f"Failed to fetch the sitemap page: {e}")
        base_bool = False
    except ET.ParseError as e:
        print(f"Failed to parse the sitemap XML: {e}")
        base_bool = False

    return page_urls, base_bool

# url = 'https://www.apolomarketing.net'
# pages = fetch_sitemap(url)
# print(pages)

# %%
urls_executor = ThreadPoolExecutor(12)
relevant_executor = ThreadPoolExecutor(12)
def sirenGPT(url):
    try:
        all_pages, base_bool = fetch_sitemap(format_url(url))
        if base_bool == False:
            all_pages = extract_all_links(format_url(url))
    except Exception as e:
        all_pages = extract_all_links(format_url(url))

        
    futures_all_pages = []
    relevant = set()
    print("Enriching...", url)

    for page in all_pages:
        future = urls_executor.submit(generate_response_gpt3_json, (prompt_legal + str(page)))
        futures_all_pages.append(future)
    
    for future in futures_all_pages:
        result = future.result()
        result_json = json.loads(result)
        legal = result_json["legal"]
        if legal == "yes":
            relevant.add(result_json["relevant_link"])
    
    
    print("Found", len(relevant), "relevant pages.")
    print(relevant)
    full_text = ""
    if len(relevant) > 0:
        for page in relevant:
            html = retieve_url(format_url(page), html=True)
            full_text += get_html(html)
    
        response = generate_response(prompt_siret + header_siret + full_text)
        print(response)
        result_json = json.loads(response)
        final_result = result_json["siren/siret"]

        return final_result
    else:
        return "Nothing found"

# %%
#sirenGPT("https://evergrowth.com")

# %%
import signal
import time

class TimeoutException(Exception):
    pass

def timeout_handler(signum, frame):
    raise TimeoutException

def run_function_with_timeout(url):
    signal.signal(signal.SIGALRM, timeout_handler)
    signal.alarm(60)  

    try:
        start_time = time.time()
        
        result = sirenGPT(url)
        
        elapsed_time = time.time() - start_time
        print(f"sirenGPT: Completed in {elapsed_time:.2f} seconds.")
        
        signal.alarm(0)
        print("\n")
        return result
    
    except TimeoutException:
        print('Result took too long to output.')
        print("\n")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        print("\n")
        return None

signal.alarm(0)
# Out:
# 0

# %%
#run_function_with_timeout("https://groupe-coreal.fr/")

# %% [markdown]
# #### To enrich fully

# %%
import pandas as pd
df = pd.read_csv('test_enrichments/Untitled spreadsheet - Sheet2 (24).csv')
df
# Out:
#          SIREN                    COMPANY_DOMAIN
# 0    484299854                 3cdbagencement.fr
# 1    528215270               abak-ingenierie.com
# 2    329904254                          abest.fr
# 3    509087672                     aconstruct.fr
# 4    315814228                     peintisol.net
# ..         ...                               ...
# 218  329152763  var-amenagement-developpement.fr
# 219   63802276                         vivian.fr
# 220  324847003                       vldparis.fr
# 221  342645504                     wiame-vrd.com
# 222  414983916                       zaniersa.fr
#
# [223 rows x 2 columns]

# %%
df['result'] = None

# %%
# for index, row in df.iterrows():
#     company_domain = row['COMPANY_DOMAIN']
#     result = run_function_with_timeout(company_domain)
#     df.at[index, 'result'] = result

# df.to_csv('siren_siret_results.csv', index=False)

# %%
import concurrent.futures
import pandas as pd

# Assuming df is your DataFrame and run_function_with_timeout is defined

def worker(row):
    index, data = row
    company_domain = data['COMPANY_DOMAIN']
    result = sirenGPT(company_domain)
    return index, result

def update_results(future):
    index, result = future.result()
    df.at[index, 'result'] = result

with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
    # Submitting all jobs to the executor
    futures = [executor.submit(worker, row) for row in df.iterrows()]
    
    # Optional: If you want to update the DataFrame as tasks complete
    # you can attach a callback to each future that will update the DataFrame
    # with the result once the future is done.
    for future in futures:
        future.add_done_callback(update_results)

# Save the updated DataFrame to CSV
df.to_csv('siren_siret_results.csv', index=False)
# Out:
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.peintisol.net', port=443): Max retries exceeded with url: /sitemap.xml (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12f876a50>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Failed to parse the sitemap XML: not well-formed (invalid token): line 94, column 18
# Enriching... abest.fr
# Found 1 relevant pages.
# {'https://www.abest.fr/en/legal'}
# Enriching... aconstruct.fr
# Found 1 relevant pages.
# {'https://www.aconstruct.fr/fr/mentions-legales'}
# Enriching... 3cdbagencement.fr
# {
#     "siren/siret": "Not found"
# }
# Found 0 relevant pages.
# set()
# {
#     "siren/siret": "Not found"
# }
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.agb-gle.com/sitemap.xml
# Enriching... agb-gle.com
# Found 0 relevant pages.
# set()
# Enriching... agtherm.com
# Enriching... afeo.fr
# Found 1 relevant pages.
# {'https://www.agtherm.com/legal'}
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.agi2d.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.agi2d.fr'. (_ssl.c:1006)")))
# /var/folders/n_/wl87mr752wgdjn7jyt7_09640000gn/T/ipykernel_63449/1947427079.py:5: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(response.text, 'html.parser')
# Enriching... agi2d.fr
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 403 Client Error: Forbidden for url: https://alcena.fr/sitemap.xml
# {
#     "siren/siret": "Not found"
# }
# Enriching... alcena.fr
# Found 0 relevant pages.
# set()
# Enriching... ageo-construction.com
# Enriching... aen-energies.io
# Found 0 relevant pages.
# set()
# Enriching... abak-ingenierie.com
# Found 0 relevant pages.
# set()
# Found 1 relevant pages.
# {'https://www.abak-ingenierie.com/mentions-legales/'}
# Enriching... altempo.com
# Enriching... alphacontrole.com
# Enriching... peintisol.net
# Found 5 relevant pages.
# {'https://www.altempo.com/documentation/', 'https://www.altempo.com/securisation-chantier/', 'https://www.altempo.com/temposynch/', 'https://www.altempo.com/logistique-chantier/', 'https://www.altempo.com/signaletique-chantier/'}
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Enriching... alfacoustic.com
# Found 0 relevant pages.
# set()
# Failed to parse the sitemap XML: undefined entity: line 15, column 0
# {
#     "siren/siret": "Not found"
# }
# Enriching... amoservices.pro
# Enriching... amenagement77.fr
# Enriching... alto-ingenierie.fr
# Found 3 relevant pages.
# {'https://www.amoservices.pro/presentation/responsables-poles/', 'https://www.amoservices.pro/mentions-legales', 'https://www.amoservices.pro/mentions-legales/'}
# Found 0 relevant pages.
# set()
# Enriching... amocer-group.com
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 500 Server Error: Internal Server Error for url: https://www.antona-et-cofi.fr/sitemap.xml
# {
#     "siren/siret": "Not found"
# }
# Enriching... ana-ingenierie.fr
# Enriching... amodev.eu
# Found 2 relevant pages.
# {'https://www.ana-ingenierie.fr/copie-de-hotellerie', 'https://www.ana-ingenierie.fr/copie-de-industrie'}
# Found 1 relevant pages.
# {'http://www.amodev.eu/notre-bureau/'}
# Enriching... antona-et-cofi.fr
# Found 0 relevant pages.
# set()
# {
#     "siren/siret": "Not found"
# }
# {
#     "siren/siret": "Not found"
# }
# Enriching... aquadim.fr
# {
#     "siren/siret": "50393469700049"
# }
# Enriching... atemco.fr
# Found 2 relevant pages.
# {'https://www.aquadim.fr/mentions-legales/', 'https://www.aquadim.fr/politique-de-cookies-ue/'}
# Found 1 relevant pages.
# {'https://www.atemco.fr/mentions-legales.php'}
# Enriching... entrepriseap2r.fr
# Found 0 relevant pages.
# set()
# {
#     "siren/siret": "53392551700021"
# }
# {
#     "siren/siret": "Not found"
# }
# Enriching... ateliersperrault.com
# Enriching... arcora.com
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Enriching... axl-constructions.fr
# Enriching... atixis.com
# Enriching... baniti.fr
# Enriching... axiolis.com
# Found 0 relevant pages.
# set()
# Found 4 relevant pages.
# {'https://www.atixis.com/en/legal', 'https://www.atixis.com/en/legal-notice/', 'https://www.atixis.com/en/company/', 'https://www.atixis.com/en/legal-notice'}
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Enriching... axoe.fr
# Found 0 relevant pages.
# set()
# Enriching... batietanche.fr
# Enriching... becia.fr
# Found 0 relevant pages.
# set()
# Enriching... barbanel.fr
# Failed to fetch the sitemap: 436 Client Error:  for url: http://ww16.bellegarde-ing.com/sitemap.xml?sub1=20240410-2313-540b-8fa1-89d173089c23
# Enriching... sylvametal.com
# Enriching... bellegarde-ing.com
# Found 1 relevant pages.
# {'https://www.becia.fr/mentions-legales'}
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Enriching... berga.fr
# Failed to parse the sitemap XML: junk after document element: line 6, column 2
# {
#     "siren/siret": "702047812"
# }
# Found 0 relevant pages.
# set()
# {
#     "siren/siret": "789729472"
# }
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.bimingenierie.fr/sitemap.xml
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.bres-sa.fr/sitemap.xml
# Enriching... betom-ingenierie.fr
# Enriching... bg-constructions.fr
# Enriching... bres-sa.fr
# Enriching... bimingenierie.fr
# Found 1 relevant pages.
# {'https://www.betom-ingenierie.fr/mentions-legales/'}
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Enriching... briand-sas.fr
# Found 1 relevant pages.
# {'https://www.bimingenierie.fr/mentions-legales/'}
# Enriching... ltdfluides.com
# {
#     "siren/siret": "Not found"
# }
# {
#     "siren/siret": "Not found"
# }
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.tramoy.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.tramoy.fr'. (_ssl.c:1006)")))
# Found 2 relevant pages.
# {'http://www.briand-sas.fr/liens-briand.html', 'http://www.briand-sas.fr/protection-donnees-personnelles.html'}
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.cairn-ingenierie.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.cairn-ingenierie.fr'. (_ssl.c:1006)")))
# Enriching... cairn-ingenierie.fr
# Enriching... benedetti-sa.fr
# Found 0 relevant pages.
# set()
# Found 1 relevant pages.
# {'https://www.benedetti-sa.fr/Benedetti/cookielawinfo/politique-cookie'}
# {
#     "siren/siret": "Not found"
# }
# Enriching... tramoy.fr
# {
#     "siren/siret": "Not found"
# }
# Failed to parse the sitemap XML: not well-formed (invalid token): line 1, column 56
# Found 0 relevant pages.
# set()
# Enriching... cerazur.com
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://cet-ingenierie.fr/wp-sitemap.xml
# Enriching... cdes.pro
# Enriching... capocci.fr
# Enriching... cet-ingenierie.fr
# Enriching... ceingenierie.fr
# Found 0 relevant pages.
# set()
# Found 1 relevant pages.
# {'https://cerazur.com/legal'}
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.chapescoutinho.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLError(1, '[SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006)')))
# Enriching... cf-services.com
# Found 0 relevant pages.
# set()
# Enriching... sas-chapelec.com
# Enriching... charpentier-sas.com
# Found 1 relevant pages.
# {'https://www.sas-chapelec.com/toiture-vegetalisee.php'}
# {
#     "siren/siret": "Not found"
# }
# Found 0 relevant pages.
# set()
# Enriching... cetrac.fr
# {
#     "siren/siret": "Not found"
# }
# Found 4 relevant pages.
# {'https://www.cetrac.fr/category/agro-alimentaire/', 'https://www.cetrac.fr/metiers/', 'https://www.cetrac.fr/mentions-legales', 'https://www.cetrac.fr/category/logements/'}
# Enriching... cide-elec.fr
# Found 1 relevant pages.
# {'https://www.cide-elec.fr/mentions-legales/'}
# Enriching... chapescoutinho.fr
# Found 0 relevant pages.
# set()
# {
#     "siren/siret": "345260988"
# }
# Failed to fetch the sitemap: 403 Client Error: Forbidden for url: https://www.entreprise-club.fr/sitemap.xml
# Enriching... entreprise-club.fr
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.concept-resine.com/sitemap.xml
# Enriching... concept-resine.com
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 500 Server Error: Internal Server Error for url: https://www.coredif.com/sitemap.xml
# Enriching... citadis.fr
# Enriching... coredif.com
# Found 0 relevant pages.
# set()
# Found 1 relevant pages.
# {'https://www.coredif.com/contact/'}
# Failed to fetch the sitemap page: 404 Client Error: Not Found for url: https://corelo.fr/project_category-sitemap.xml
# {
#     "siren/siret": "Not found"
# }
# {
#     "siren/siret": "Not found"
# }
# Enriching... martelgroupe.fr
# Found 1 relevant pages.
# {'https://www.martelgroupe.fr/filiales/'}
# Enriching... corelo.fr
# Found 0 relevant pages.
# set()
# Failed to parse the sitemap XML: junk after document element: line 10, column 4
# {
#     "siren/siret": "Not found"
# }
# Enriching... dasse.com
# Enriching... eiffage-demcy.com
# Found 0 relevant pages.
# set()
# Enriching... demattec.fr
# Failed to fetch the sitemap: 410 Client Error: Gone for url: https://www.bet-dexo.fr/sitemap.xml
# Enriching... cruard-charpente.com
# Found 1 relevant pages.
# {'https://www.eiffage-demcy.com:443/legal'}
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Enriching... duvaletmauler.fr
# Enriching... bet-dexo.fr
# Found 1 relevant pages.
# {'https://duvaletmauler.fr/en/legal'}
# {
#     "siren/siret": "Not found"
# }
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.ekkoplus.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1006)')))
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.elecsbe.com/sitemap.xml
# Enriching... climascience.com
# Enriching... elecsbe.com
# {
#     "siren/siret": "Not found"
# }
# Found 2 relevant pages.
# {'https://www.climascience.com/legal', 'https://www.climascience.com/references/travaux/'}
# Found 0 relevant pages.
# set()
# Enriching... e2j.fr
# Enriching... empeering.fr
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 403 Client Error: Forbidden for url: https://www.emrbtp.fr/sitemap.xml
# Enriching... eliez.fr
# Enriching... emrbtp.fr
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.energys-sas.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLError(1, '[SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006)')))
# {
#     "siren/siret": "34072550600059"
# }
# Enriching... mederreg.fr
# Found 0 relevant pages.
# set()
# Enriching... energelio.fr
# Enriching... ekkoplus.fr
# Found 0 relevant pages.
# set()
# Enriching... roussiere.fr
# Found 0 relevant pages.
# set()
# Enriching... essonne-tp.fr
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Enriching... etirem.fr
# Enriching... etancheitedunord.com
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.hanny.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.hanny.fr'. (_ssl.c:1006)")))
# Enriching... prunevieille.fr
# Found 0 relevant pages.
# set()
# Enriching... hanny.fr
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.euromib.fr/sitemap.xml
# Enriching... euromib.fr
# Enriching... etamine.coop
# Found 0 relevant pages.
# set()
# Enriching... eurotechfloor.fr
# Found 0 relevant pages.
# set()
# Found 1 relevant pages.
# {'https://www.etamine.coop/recrutement/'}
# Enriching... energys-sas.fr
# {
#     "siren/siret": "Not found"
# }
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.feldisleviaux.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://faceagroup.com/sitemap.xml
# Enriching... etyo.com
# Enriching... faceagroup.com
# Enriching... feldisleviaux.fr
# Enriching... exetanch.fr
# Found 2 relevant pages.
# {'https://www.etyo.com/legal', 'https://www.etyo.com/en/home/about/'}
# Found 1 relevant pages.
# {'https://www.faceagroup.com/tohier'}
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: http://www.foret-ent.fr/sitemap.xml
# Found 3 relevant pages.
# {'https://www.exetanch.fr/service-de-supervision-des-chantiers/', 'https://www.exetanch.fr/contact/', 'https://www.exetanch.fr/securisation-2/'}
# Enriching... foret-ent.fr
# Found 1 relevant pages.
# {'http://www.foret-ent.fr/index.php/mentions-legales/#cookies'}
# {
#     "siren/siret": "Not found"
# }
# {
#     "siren/siret": "34996178900030"
# }
# Enriching... franchiandco.com
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 403 Client Error: Forbidden for url: https://www.genere.fr/sitemap.xml
# {
#     "siren/siret": "Not found"
# }
# Enriching... geolia-conseil.com
# Found 2 relevant pages.
# {'https://www.geolia-conseil.com/environnement', 'https://www.geolia-conseil.com/mentions-legales'}
# Enriching... genere.fr
# Found 0 relevant pages.
# set()
# Failed to parse the sitemap XML: no element found: line 124, column 9
# Enriching... gerelec.fr
# {
#     "siren/siret": "Not found"
# }
# Found 1 relevant pages.
# {'https://www.gerelec.fr/politique-confidentialite'}
# Enriching... gceb.info
# {
#     "siren/siret": "Not found"
# }
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.ett-sa.fr/sitemap.xml
# Enriching... ett-sa.fr
# Enriching... coreal.pro
# Found 4 relevant pages.
# {'https://www.gceb.info/categorie-realisation/copropriete-type-douvrage-facade/', 'https://www.gceb.info/mentions-legales/', 'https://www.gceb.info/lexique/', 'https://www.gceb.info/contact/'}
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# {
#     "siren/siret": "Not found"
# }
# Enriching... harribeyconstructions.fr
# Enriching... hchevalier.com
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.energem-france.com', port=443): Max retries exceeded with url: /sitemap.xml (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x13a5e1350>, 'Connection to www.energem-france.com timed out. (connect timeout=None)'))
# Found 2 relevant pages.
# {'https://www.harribeyconstructions.fr/recrutement/', 'https://www.harribeyconstructions.fr/recrutement'}
# Found 2 relevant pages.
# {'https://www.hchevalier.com/certifications-labels/', 'https://www.hchevalier.com/legal'}
# Enriching... gtaenergies.fr
# {
#     "siren/siret": "Not found"
# }
# Found 0 relevant pages.
# set()
# {
#     "siren/siret": "Not found"
# }
# {
#     "siren/siret": "Not found"
# }
# Enriching... i-plus-a.fr
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.icecs.fr/sitemap.xml
# Enriching... herkrug.fr
# Enriching... icecs.fr
# Found 0 relevant pages.
# set()
# Enriching... hexa-ingenierie.com
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Found 1 relevant pages.
# {'https://www.hexa-ingenierie.com/mentions-legales/'}
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.iliade-ingenierie.com/sitemap.xml
# Enriching... iliade-ingenierie.com
# Enriching... y-ingenierie.com
# Found 2 relevant pages.
# {'https://www.iliade-ingenierie.com/newsletters.html', 'https://www.iliade-ingenierie.com/mentions-legales.html'}
# {
#     "siren/siret": "Not found"
# }
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.incet.fr/sitemap.xml
# Enriching... incet.fr
# {
#     "siren/siret": "Not found"
# }
# Found 4 relevant pages.
# {'https://www.y-ingenierie.com/en/legal-notice/', 'https://www.y-ingenierie.com/en/credits/', 'https://www.y-ingenierie.com/en/legal', 'https://www.y-ingenierie.com/en/our-reference/'}
# Enriching... icofluides.fr
# Found 2 relevant pages.
# {'https://www.incet.fr/en/legal', 'https://www.incet.fr/fr/p/10/actualites'}
# Found 0 relevant pages.
# set()
# Enriching... energem-france.com
# Found 0 relevant pages.
# set()
# Enriching... ingenierie84.fr
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://innovation-fluides.com/sitemap.xml
# Enriching... innovation-fluides.com
# Found 2 relevant pages.
# {'https://www.innovation-fluides.com/mentions-legales', 'https://www.innovation-fluides.com/projet/bureaux-paris-saint-lazare'}
# {
#     "siren/siret": "Not found"
# }
# Enriching... ingebime.fr
# {
#     "siren/siret": "784564197"
# }
# Found 0 relevant pages.
# set()
# Enriching... iph-bet.fr
# {
#     "siren/siret": "Not found"
# }
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 403 Client Error: Forbidden for url: https://www.jdcharpente.fr/sitemap.xml
# Enriching... isotop-etancheite.fr
# Found 0 relevant pages.
# set()
# Enriching... jfeconcept.com
# Enriching... jdcharpente.fr
# Found 2 relevant pages.
# {'https://www.jfeconcept.com/politique-de-confidentialité', 'https://www.jfeconcept.com/politique-de-cookies'}
# Found 0 relevant pages.
# set()
# Enriching... inex.fr
# Enriching... isf-energies.com
# Enriching... khephren.fr
# Found 1 relevant pages.
# {'https://www.inex.fr/methodes-et-simulations-cfd/rd/nos-brevets-deposes/'}
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# {
#     "siren/siret": "Not found"
# }
# Enriching... lartetlebois.fr
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.la-louisiane.fr/sitemap.xml
# Enriching... jcpentreprise.com
# Found 0 relevant pages.
# set()
# {
#     "siren/siret": "Not found"
# }
# Failed to parse the sitemap XML: XML or text declaration not at start of entity: line 2, column 0
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.lebatimentassocie.fr/sitemap.xml
# Enriching... lebatimentassocie.fr
# Enriching... la-louisiane.fr
# Enriching... lamoureux-ricciotti.com
# Found 1 relevant pages.
# {'https://www.lebatimentassocie.fr/fr/mentions-legales'}
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Enriching... latelierdesfluides.com
# Failed to parse the sitemap XML: XML or text declaration not at start of entity: line 4, column 0
# {
#     "siren/siret": "Not found"
# }
# Enriching... le-bras-freres.fr
# Found 0 relevant pages.
# set()
# Enriching... lesagenceurs.fr
# Found 0 relevant pages.
# set()
# Failed to parse the sitemap XML: no element found: line 1, column 0
# Enriching... lgx.fr
# Found 3 relevant pages.
# {'https://www.lesagenceurs.fr/archives/portfolio/concept-global-26', 'https://www.lesagenceurs.fr/archives/portfolio/librairie-quai-des-brumes', 'https://www.lesagenceurs.fr/archives/portfolio/frankys-diner-etoile'}
# Enriching... lizsol.fr
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Enriching... l2a-agencement.com
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://lte-construction.fr/wp-sitemap.xml
# Enriching... lte-construction.fr
# Found 0 relevant pages.
# set()
# Enriching... m2esa.fr
# {
#     "siren/siret": "Not found"
# }
# Enriching... menuiserie-aluminium-willot-venette.fr
# Found 0 relevant pages.
# set()
# Enriching... cdcsas.fr
# Enriching... mbo77.fr
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 403 Client Error: Forbidden for url: https://www.moduo.fr/sitemap.xml
# Enriching... moduo.fr
# Enriching... mgbr.fr
# Found 3 relevant pages.
# {'https://www.cdcsas.fr/contact/', 'https://www.cdcsas.fr/project/chateauvallon/', 'https://www.cdcsas.fr/mentions-legales'}
# Found 0 relevant pages.
# set()
# Enriching... mecobat.com
# Failed to parse the sitemap XML: not well-formed (invalid token): line 45, column 73
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Found 2 relevant pages.
# {'https://www.moduo.fr/mentions-legales/', 'https://www.moduo.fr/conseil/'}
# Enriching... montelec.fr
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# {
#     "siren/siret": "Not found"
# }
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.mv2acro.com', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.mv2acro.com'. (_ssl.c:1006)")))
# Failed to fetch the sitemap page: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# {
#     "siren/siret": "81078405800010"
# }
# Enriching... mpofenetres.com
# Enriching... modern-restauration-gestion.com
# Found 0 relevant pages.
# set()
# Enriching... ovatis.fr
# Failed to parse the sitemap XML: undefined entity: line 38, column 0
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Failed to parse the sitemap XML: not well-formed (invalid token): line 16, column 159
# Failed to parse the sitemap XML: undefined entity: line 38, column 0
# Enriching... mv2acro.com
# Failed to parse the sitemap XML: undefined entity: line 38, column 0
# Found 0 relevant pages.
# set()
# Enriching... oxiumgroup.fr
# Enriching... ppe95.fr
# Found 0 relevant pages.
# set()
# Enriching... nrgys.fr
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.semplaine.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))
# Found 2 relevant pages.
# {'https://www.nrgys.fr/certifications/', 'https://www.nrgys.fr/mentions-legales/'}
# Enriching... semplaine.fr
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.planet-energy-concept.com', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.planet-energy-concept.com'. (_ssl.c:1006)")))
# {
#     "siren/siret": "487481574"
# }
# Enriching... planet-energy-concept.com
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 503 Server Error: Service Unavailable for url: https://www.pouget-consultants.eu/sitemap.xml
# Enriching... pcamaisons.com
# Found 0 relevant pages.
# set()
# Enriching... poulingue.fr
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.prelem.com/sitemap.xml
# Enriching... prelem.com
# Enriching... pouget-consultants.eu
# Enriching... plbenergieconseil.com
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.progerep.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))
# Enriching... mvbatiment.fr
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.provencetp.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate (_ssl.c:1006)')))
# Enriching... progerep.fr
# Enriching... provencetp.fr
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.qivy-habitat.fr/sitemap.xml
# Enriching... primiso.fr
# Enriching... qivy-habitat.fr
# Found 1 relevant pages.
# {'https://www.primiso.fr/mentions-legales'}
# Found 1 relevant pages.
# {'https://www.qivy-habitat.fr/cookies/'}
# {
#     "siren/siret": "Not found"
# }
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.r3s-france.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate (_ssl.c:1006)')))
# {
#     "siren/siret": "49039081200025"
# }
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.ragoucy.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.ragoucy.fr'. (_ssl.c:1006)")))
# Enriching... ragoucy.fr
# Found 0 relevant pages.
# set()
# Enriching... r3s-france.fr
# Enriching... ratpmaintenanceservices.com
# Found 0 relevant pages.
# set()
# Enriching... reaconcept.fr
# Found 3 relevant pages.
# {'https://www.ratpmaintenanceservices.com/legal', 'https://www.ratpmaintenanceservices.com/politique-cookies', 'https://www.ratpmaintenanceservices.com/entreprise'}
# Found 2 relevant pages.
# {'http://www.reaconcept.fr/services.html', 'http://www.reaconcept.fr/mentions-legales.php'}
# Enriching... provence-vrd.com
# Found 0 relevant pages.
# set()
# {
#     "siren/siret": "Not found"
# }
# Failed to fetch the sitemap: 403 Client Error: Forbidden for url: https://www.betrbs.fr/sitemap.xml
# Enriching... realsol.fr
# Enriching... betrbs.fr
# {
#     "siren/siret": "Not found"
# }
# Enriching... recipro-cite.com
# Found 0 relevant pages.
# set()
# Found 1 relevant pages.
# {'https://www.betrbs.fr/mentions-legales'}
# Enriching... renover.fr
# {
#     "siren/siret": "Not found"
# }
# Failed to parse the sitemap XML: not well-formed (invalid token): line 20, column 68
# Found 0 relevant pages.
# set()
# Found 1 relevant pages.
# {'https://www.renover.fr/logements'}
# Enriching... rgbfrance.com
# Found 0 relevant pages.
# set()
# {
#     "siren/siret": "431229491"
# }
# Failed to parse the sitemap XML: mismatched tag: line 25, column 2
# Enriching... richezassocies.com
# Enriching... rhin-climatisation.fr
# Found 3 relevant pages.
# {'https://www.richezassocies.com/fr/4-leviers-1-lab/leviers/urbanite-durable', 'https://www.richezassocies.com/en/legal', 'https://www.richezassocies.com/fr/mentions-legales'}
# Found 1 relevant pages.
# {'https://www.rhin-climatisation.fr/mentions-legales/'}
# {
#     "siren/siret": "67850167700028"
# }
# Enriching... roissy-tp.fr
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.pian-entreprise.com', port=443): Max retries exceeded with url: /sitemap.xml (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x13f11f9d0>, 'Connection to www.pian-entreprise.com timed out. (connect timeout=None)'))
# Enriching... rolaix.com
# Enriching... roc-confortation.fr
# {
#     "siren/siret": "332429398"
# }
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.r-o-m.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x13f0f1850>: Failed to resolve 'www.r-o-m.fr' ([Errno 8] nodename nor servname provided, or not known)"))
# Enriching... r-o-m.fr
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://routesetchantiersmodernes.com/sitemap.xml
# Enriching... s2t.fr
# Enriching... routesetchantiersmodernes.com
# Enriching... pian-entreprise.com
# Found 3 relevant pages.
# {'https://www.s2t.fr/books-s2t/', 'https://www.s2t.fr/contact/', 'https://www.s2t.fr/expertises/'}
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.santerne-idf.fr/sitemap.xml
# Enriching... sadev94.fr
# Found 0 relevant pages.
# set()
# Enriching... santerne-idf.fr
# Found 1 relevant pages.
# {'https://www.santerne-idf.fr/rse/'}
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.santerne-tertiaire-sante.fr/sitemap.xml
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.sarmates.fr/sitemap.xml
# {
#     "siren/siret": "510411200"
# }
# Enriching... eitb06.com
# Enriching... santerne-tertiaire-sante.fr
# {
#     "siren/siret": "Not found"
# }
# Enriching... sarmates.fr
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Found 1 relevant pages.
# {'https://www.sarmates.fr/index.php/contact/'}
# Enriching... schneider-cie.fr
# Found 2 relevant pages.
# {'https://www.schneider-cie.fr/metiers/', 'https://www.schneider-cie.fr/mentions-legales'}
# {
#     "siren/siret": "Not found"
# }
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.sedri.fr/sitemap.xml
# Enriching... scyna4.fr
# Enriching... sedri.fr
# Found 1 relevant pages.
# {'https://www.scyna4.fr/fr/rse/'}
# Found 1 relevant pages.
# {'https://www.sedri.fr/projet/sways'}
# {
#     "siren/siret": "95420080400019"
# }
# Failed to fetch the sitemap: 403 Client Error: Forbidden for url: https://www.seef.fr/sitemap.xml
# Enriching... sbglutece.com
# {
#     "siren/siret": "Not found"
# }
# {
#     "siren/siret": "Not found"
# }
# Found 0 relevant pages.
# set()
# Enriching... seef.fr
# Found 0 relevant pages.
# set()
# Enriching... semapa.fr
# Enriching... semofi-groupe.fr
# Found 2 relevant pages.
# {'https://www.semapa.fr/mentions-legales', 'https://www.semapa.fr/mentions-legales/'}
# Enriching... senova.fr
# Found 0 relevant pages.
# set()
# Enriching... sept-resine.com
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.sinteo.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://sigma-ing.fr/sitemap.xml
# {
#     "siren/siret": "Not found"
# }
# Enriching... sinteo.fr
# Enriching... sigma-ing.fr
# Enriching... socateb.com
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.solconseil.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.sol-essais.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))
# Found 2 relevant pages.
# {'https://www.socateb.com/contact', 'https://www.socateb.com/mentions-legales'}
# Enriching... sol-essais.fr
# Found 0 relevant pages.
# set()
# Enriching... solconseil.fr
# Found 0 relevant pages.
# set()
# Enriching... sos-murs-rideaux.com
# Failed to fetch the sitemap: 500 Server Error: Internal Server Error for url: https://soleffi.fr/sitemap_index.xml
# {
#     "siren/siret": "Not found"
# }
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.stpif.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.stpif.fr'. (_ssl.c:1006)")))
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.sotrelec.fr/sitemap.xml
# Enriching... sogeti-ingenierie.fr
# Enriching... sotrelec.fr
# Enriching... stpif.fr
# Enriching... soleffi.fr
# Found 0 relevant pages.
# set()
# Enriching... studetech.fr
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.sudconstruction.com/sitemap.xml
# Failed to fetch the sitemap: HTTPSConnectionPool(host='www.sud-est-etancheite.fr', port=443): Max retries exceeded with url: /sitemap.xml (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.sud-est-etancheite.fr'. (_ssl.c:1006)")))
# Enriching... sudconstruction.com
# Found 0 relevant pages.
# set()
# Enriching... sud-est-etancheite.fr
# Found 0 relevant pages.
# set()
# Enriching... tci-treuil.fr
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Enriching... tempere-construction.fr
# Enriching... synacoustique.com
# Enriching... telerep.fr
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Enriching... tribu-energie.fr
# Enriching... tbes.fr
# Found 5 relevant pages.
# {'https://www.telerep.fr/cgv/', 'https://www.telerep.fr/recrutement/', 'https://www.telerep.fr/contact/', 'https://www.telerep.fr/agences/', 'https://www.telerep.fr/mentions-legales/'}
# Enriching... tem-france.fr
# Found 0 relevant pages.
# set()
# Enriching... urbacite-amenagements.fr
# Found 2 relevant pages.
# {'https://www.tbes.fr/nos-engagements-recruter/', 'https://www.tbes.fr/politique-de-cookies/'}
# Found 0 relevant pages.
# set()
# Found 0 relevant pages.
# set()
# Enriching... uretek.fr
# Enriching... var-amenagement-developpement.fr
# {
#     "siren/siret": "Not found"
# }
# {
#     "siren/siret": "35132065000051"
# }
# Enriching... vldparis.fr
# Enriching... vivian.fr
# Found 3 relevant pages.
# {'https://www.uretek.fr/documents/encart-collectivit-s-locales', 'https://www.uretek.fr/documents/secheresse-uretek-une-solution-courante', 'https://www.uretek.fr/documents/catalogue-uretek'}
# Found 1 relevant pages.
# {'https://www.var-amenagement-developpement.fr/legal/'}
# Found 0 relevant pages.
# set()
# Failed to fetch the sitemap: 404 Client Error: Not Found for url: https://www.wiame-vrd.com/sitemap.xml
# {
#     "siren/siret": "32915276300028"
# }
# Found 0 relevant pages.
# set()
# Enriching... zaniersa.fr
# Enriching... wiame-vrd.com
# Found 0 relevant pages.
# set()
# {
#     "siren/siret": "Not found"
# }
# Found 1 relevant pages.
# {'https://www.wiame-vrd.com/qse/les-abeilles-chez-wiame-vrd'}
# {
#     "siren/siret": "Not found"
# }
# Failed to fetch the sitemap: 502 Server Error: Proxy Error for url: https://www.groupe-prestibat.com/sitemap.xml
# Enriching... groupe-prestibat.com
# Found 1 relevant pages.
# {'https://www.groupe-prestibat.com/protection-donnees-personnelles'}
# {
#     "siren/siret": "Not found"
# }

# %%
results = pd.read_csv('/Users/ismadoukkali/Desktop/industryGPT/industryGPT/scalability/siren_siret_results.csv')
results
# Out:
#          SIREN                    COMPANY_DOMAIN          result
# 0    484299854                 3cdbagencement.fr   Nothing found
# 1    528215270               abak-ingenierie.com       Not found
# 2    329904254                          abest.fr       Not found
# 3    509087672                     aconstruct.fr       Not found
# 4    315814228                     peintisol.net   Nothing found
# ..         ...                               ...             ...
# 218  329152763  var-amenagement-developpement.fr  32915276300028
# 219   63802276                         vivian.fr   Nothing found
# 220  324847003                       vldparis.fr   Nothing found
# 221  342645504                     wiame-vrd.com       Not found
# 222  414983916                       zaniersa.fr   Nothing found
#
# [223 rows x 3 columns]

# %%
# Attempt to convert the 'result' column to numeric, coerce errors to NaN
numeric_results = pd.to_numeric(df['result'], errors='coerce')

# Count the number of non-NaN values, which are the numeric entries
num_numeric_entries = numeric_results.notna().sum()

print(num_numeric_entries)
# Out:
# 18
